# %% [markdown]
# <a href="https://colab.research.google.com/github/Dimasputra2530/Data-Slayer/blob/main/Data_Slayer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

print(os.listdir("data_slayer"))
print(os.listdir("data_slayer/train")[:10])
# Out:
# ['train', 'sample_submission.csv', 'test']
# ['drowsiness', 'non-drowsiness']

# %% [markdown]
# # library

# %%
# Basic
import numpy as np
import pandas as pd

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# ML tools
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import accuracy_score, f1_score

# ML models
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

# Deep Learning
import tensorflow as tf

# Utility
import os
from tqdm import tqdm
import cv2

# %% [markdown]
# # CEK JUMLAH DATA TRAIN

# %%
base_path = "/content/data_slayer/train"

for cls in os.listdir(base_path):
    cls_path = os.path.join(base_path, cls)
    if os.path.isdir(cls_path):
        print(cls, ":", len(os.listdir(cls_path)), "images")
# Out:
# drowsiness : 15 images
# non-drowsiness : 15 images

# %% [markdown]
# # CEK JUMLAH DATA TEST

# %%
base_path = "/content/data_slayer/test"

for cls in os.listdir(base_path):
    cls_path = os.path.join(base_path, cls)
    if os.path.isdir(cls_path):
        print(cls, ":", len(os.listdir(cls_path)), "images")
# Out:
# test_seq_00543 : 30 images
# test_seq_00100 : 30 images
# test_seq_00095 : 30 images
# test_seq_00145 : 30 images
# test_seq_00376 : 30 images
# test_seq_00428 : 30 images
# test_seq_00519 : 30 images
# test_seq_00139 : 30 images
# test_seq_00414 : 30 images
# test_seq_00385 : 30 images
# test_seq_00546 : 30 images
# test_seq_00544 : 30 images
# test_seq_00200 : 30 images
# test_seq_00494 : 30 images
# test_seq_00187 : 30 images
# test_seq_00362 : 30 images
# test_seq_00186 : 30 images
# test_seq_00598 : 30 images
# test_seq_00158 : 30 images
# test_seq_00161 : 30 images
# test_seq_00453 : 30 images
# test_seq_00137 : 30 images
# test_seq_00222 : 30 images
# test_seq_00370 : 30 images
# test_seq_00589 : 30 images
# test_seq_00250 : 30 images
# test_seq_00394 : 30 images
# test_seq_00003 : 30 images
# test_seq_00509 : 30 images
# test_seq_00287 : 30 images
# test_seq_00029 : 30 images
# test_seq_00444 : 30 images
# test_seq_00115 : 30 images
# test_seq_00410 : 30 images
# ...

# %% [markdown]
# # Cek beberapa sample image

# %%
train_path = "/content/data_slayer/train"

subjects = os.listdir(train_path)
print("Jumlah subjek:", len(subjects))
subjects
# Out:
# Jumlah subjek: 2
# ['drowsiness', 'non-drowsiness']

# %%
sample_class = os.listdir(base_path)[0]
sample_path = os.path.join(base_path, sample_class)

img_name = os.listdir(sample_path)[0]
img = cv2.imread(os.path.join(sample_path, img_name))
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img)
plt.title(f"Sample from {sample_class}")
plt.axis('off')
plt.show()

# %% [markdown]
# # UKUR RATA RATA GAMBAR

# %%
sizes = []

for cls in os.listdir(base_path):
    cls_path = os.path.join(base_path, cls)
    for img_name in os.listdir(cls_path):
        img = cv2.imread(os.path.join(cls_path, img_name))
        if img is not None:
            sizes.append(img.shape[:2])  # (height, width)

sizes = np.array(sizes)
print("Rata-rata ukuran gambar:", sizes.mean(axis=0))
# Out:
# Rata-rata ukuran gambar: [ 796.5448505  1416.07973422]
